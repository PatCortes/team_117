# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/rgale/team_117/data/education.csv")

# %%
data.head()
# Out:
#            GEO_ID                     NAME  \
# 0              id     Geographic Area Name
# 1  0500000US01001  Autauga County, Alabama
# 2  0500000US01003  Baldwin County, Alabama
# 3  0500000US01005  Barbour County, Alabama
# 4  0500000US01007     Bibb County, Alabama
#
#                                       S1501_C01_001E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                               4808
# 2                                              15483
# 3                                               2090
# 4                                               1694
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                                193
# 2                                                325
# 3                                                 65
# 4                                                219
#
# ...
