# %%
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn import preprocessing
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Education:

# %%
#load education data
#include 'high school or higher' and 'college or higher' for pop 25+
col_1 = 'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 years and over'
col_2 = 'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 years and over!!High school graduate or higher'
col_3 = "Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 years and over!!Bachelor's degree or higher"
education = pd.read_csv('C:/Users/rgale/team_117/data/education.csv',skiprows=1, usecols=['id','Geographic Area Name',col_1,col_2,col_3])
#rename the columns
education = education.rename(columns={col_1:'Population 25+',col_2:'High school graduate or higher',col_3:"Bachelor's degree or higher",'Geographic Area Name':'Location'})
education.head()
# Out:
#                id                 Location  Population 25+  \
# 0  0500000US01001  Autauga County, Alabama           37367
# 1  0500000US01003  Baldwin County, Alabama          151112
# 2  0500000US01005  Barbour County, Alabama           17964
# 3  0500000US01007     Bibb County, Alabama           16168
# 4  0500000US01009   Blount County, Alabama           39791
#
#    High school graduate or higher  Bachelor's degree or higher
# 0                           33076                          766
# 1                          137219                         1866
# 2                           13152                          254
# 3                           12782                          354
# 4                           32028                          498

# %%
#add column for percentage of people without a high school degree
education['pct_no_high_school_degree']=((education['Population 25+']-education['High school graduate or higher'].astype('float64'))/education['Population 25+'].astype('float64')*100)

# %%
#add column for percentage of people without a bachelor's degree
education['pct_no_college_degree']=((education['Population 25+']-education["Bachelor's degree or higher"].astype('float64'))/education['Population 25+'].astype('float64')*100)

# %%
#add FIPS code
fips = []
for county_id in education['id']:
    fips_i = county_id[-5:]
#     print(fips)
    fips.append(fips_i)

# %%
#add column with the FIPS codes
education['FIPS'] = fips
education.head()
# Out:
#                id                 Location  Population 25+  \
# 0  0500000US01001  Autauga County, Alabama           37367
# 1  0500000US01003  Baldwin County, Alabama          151112
# 2  0500000US01005  Barbour County, Alabama           17964
# 3  0500000US01007     Bibb County, Alabama           16168
# 4  0500000US01009   Blount County, Alabama           39791
#
#    High school graduate or higher  Bachelor's degree or higher  \
# 0                           33076                          766
# 1                          137219                         1866
# 2                           13152                          254
# 3                           12782                          354
# 4                           32028                          498
#
#    pct_no_high_school_degree  pct_no_college_degree   FIPS
# 0                  11.483394              97.950063  01001
# 1                   9.193843              98.765154  01003
# 2                  26.786907              98.586061  01005
# 3                  20.942603              97.810490  01007
# 4                  19.509437              98.748461  01009

# %%
#make the FIPS column into a string
education['FIPS']=education['FIPS'].astype(str)

# %% [markdown]
# # Poverty and Median Income

# %%
#read the poverty and income data 
poverty = pd.read_csv('C:/Users/rgale/team_117/data/poverty.csv', usecols=['County ID','State / County Name','All Ages in Poverty Percent','Median Household Income in Dollars'])

#rename columns
poverty = poverty.rename(columns={'County ID':'FIPS_code','All Ages in Poverty Percent':'pct_poverty','Median Household Income in Dollars':"median_income"})
poverty.head()
# Out:
#    FIPS_code  State / County Name  pct_poverty median_income
# 0          0        United States         12.3       $65,712
# 1       1000              Alabama         15.6       $51,771
# 2       1001  Autauga County (AL)         12.1       $58,233
# 3       1003  Baldwin County (AL)         10.1       $59,871
# 4       1005  Barbour County (AL)         27.1       $35,972

# %%
#make the FIPS column into a string
poverty['FIPS_code']=poverty['FIPS_code'].astype(str)

# %%
#merge data
education = pd.merge(education, poverty, left_on=['FIPS'], right_on=['FIPS_code'])

# %%
#remove unecessary columns
education=education.drop(columns=['Population 25+','High school graduate or higher',"Bachelor's degree or higher", 'FIPS_code','State / County Name', 'id'])
education.head()
# Out:
#                                      Location  pct_no_high_school_degree  \
# 0                       Kent County, Delaware                  12.565436
# 1                 New Castle County, Delaware                   8.356334
# 2                     Sussex County, Delaware                  11.879243
# 3  District of Columbia, District of Columbia                   9.076816
# 4                     Alachua County, Florida                   7.388892
#
#    pct_no_college_degree   FIPS  pct_poverty median_income
# 0              99.083470  10001         12.7       $58,804
# 1              99.356162  10003         10.4       $76,076
# 2              99.192569  10005         12.1       $64,839
# 3              99.585927  11001         14.1       $90,395
# 4              98.926612  12001         18.4       $49,880

# %% [markdown]
# # Industries

# %%
#read the industry data file
industries = pd.read_excel('C:/Users/rgale/team_117/data/industries.xlsx')

# %%
#find only the county-level rows
industries = industries.loc[(industries['Area Type'] == 'County')]

# %%
industries.head()
# Out:
#    Area\nCode  St  Cnty  Own  NAICS  Year Qtr Area Type  St Name  \
# 35      01001  01   1.0    0     10  2019   A    County  Alabama
# 36      01001  01   1.0    1     10  2019   A    County  Alabama
# 37      01001  01   1.0    2     10  2019   A    County  Alabama
# 38      01001  01   1.0    3     10  2019   A    County  Alabama
# 39      01001  01   1.0    5     10  2019   A    County  Alabama
#
#                        Area           Ownership                  Industry  \
# 35  Autauga County, Alabama       Total Covered  10 Total, all industries
# 36  Autauga County, Alabama  Federal Government  10 Total, all industries
# 37  Autauga County, Alabama    State Government  10 Total, all industries
# 38  Autauga County, Alabama    Local Government  10 Total, all industries
# 39  Autauga County, Alabama             Private  10 Total, all industries
#
#    Annual Average Status Code  Annual Average Establishment Count  \
# 35                        NaN                                 888
# 36                        NaN                                  12
# 37                        NaN                                  19
# 38                        NaN                                  32
# 39                        NaN                                 825
#
#     Annual Average Employment  Annual Total Wages  Annual Average Weekly Wage  \
# 35                      11107           448078198                         776
# 36                         82             4466579                        1043
# 37                        582            25879210                         856
# 38                       1911            73489430                         740
# 39                       8532           344242979                         776
#
#     Annual Average Pay  Employment Location Quotient Relative to U.S.  \
# 35               40344                                           1.00
# 36               54250                                           0.39
# 37               44491                                           1.66
# 38               38458                                           1.79
# 39               40349                                           0.90
#
#     Total Wage Location Quotient Relative to U.S.
# 35                                           1.00
# 36                                           0.37
# 37                                           1.73
# 38                                           1.90
# 39                                           0.90

# %%
#sum all jobs for all the industries 
totals = industries.loc[(industries['Industry'] == '10 Total, all industries') & (industries['Ownership'] == 'Total Covered')]
#this is for tourism, leisure, and hospitality: the hardest-hit industry from the pandemic shutdowns
#run similar lines to find other industries
leisure = industries.loc[(industries['Industry'] == '1026 Leisure and hospitality')]

# %%
#merge the two "totals" (all industries and leisure jobs)
leisure = pd.merge(leisure, totals, left_on='Area\nCode', right_on='Area\nCode')

# %%
#calculate the percentage of leisure jobs from the total jobs in a given county
leisure['pct_jobs_tourism_leisure_hospitality'] = leisure['Annual Average Employment_x']/leisure['Annual Average Employment_y']*100

# %%
leisure.head()
# Out:
#   Area\nCode St_x  Cnty_x  Own_x  NAICS_x  Year_x Qtr_x Area Type_x St Name_x  \
# 0      01001   01     1.0      5     1026    2019     A      County   Alabama
# 1      01003   01     3.0      5     1026    2019     A      County   Alabama
# 2      01005   01     5.0      5     1026    2019     A      County   Alabama
# 3      01007   01     7.0      5     1026    2019     A      County   Alabama
# 4      01009   01     9.0      5     1026    2019     A      County   Alabama
#
#                     Area_x Ownership_x                    Industry_x  \
# 0  Autauga County, Alabama     Private  1026 Leisure and hospitality
# 1  Baldwin County, Alabama     Private  1026 Leisure and hospitality
# 2  Barbour County, Alabama     Private  1026 Leisure and hospitality
# 3     Bibb County, Alabama     Private  1026 Leisure and hospitality
# 4   Blount County, Alabama     Private  1026 Leisure and hospitality
#
#   Annual Average Status Code_x  Annual Average Establishment Count_x  \
# 0                          NaN                                    88
# 1                          NaN                                   747
# 2                          NaN                                    63
# 3                          NaN                                    18
# 4                          NaN                                    56
#
#    Annual Average Employment_x  Annual Total Wages_x  \
# 0                         1579              22374257
# 1                        15913             337551547
# 2                          762              10266855
# 3                          200               2742476
# 4                          901              11379127
#
#    Annual Average Weekly Wage_x  Annual Average Pay_x  \
# 0                           272                 14170
# 1                           408                 21212
# 2                           259                 13471
# 3                           263                 13701
# 4                           243                 12626
#
#    Employment Location Quotient Relative to U.S._x  \
# 0                                             1.28
# 1                                             1.87
# 2                                             0.83
# 3                                             0.39
# 4                                             0.93
#
#    Total Wage Location Quotient Relative to U.S._x St_y  Cnty_y  Own_y  \
# 0                                             1.06   01     1.0      0
# 1                                             2.45   01     3.0      0
# 2                                             0.71   01     5.0      0
# 3                                             0.29   01     7.0      0
# 4                                             0.77   01     9.0      0
#
#    NAICS_y  Year_y Qtr_y Area Type_y St Name_y                   Area_y  \
# 0       10    2019     A      County   Alabama  Autauga County, Alabama
# 1       10    2019     A      County   Alabama  Baldwin County, Alabama
# 2       10    2019     A      County   Alabama  Barbour County, Alabama
# 3       10    2019     A      County   Alabama     Bibb County, Alabama
# 4       10    2019     A      County   Alabama   Blount County, Alabama
#
#      Ownership_y                Industry_y Annual Average Status Code_y  \
# 0  Total Covered  10 Total, all industries                          NaN
# 1  Total Covered  10 Total, all industries                          NaN
# 2  Total Covered  10 Total, all industries                          NaN
# 3  Total Covered  10 Total, all industries                          NaN
# 4  Total Covered  10 Total, all industries                          NaN
#
#    Annual Average Establishment Count_y  Annual Average Employment_y  \
# 0                                   888                        11107
# 1                                  6471                        76419
# 2                                   562                         8239
# 3                                   370                         4602
# 4                                   787                         8712
#
#    Annual Total Wages_y  Annual Average Weekly Wage_y  Annual Average Pay_y  \
# 0             448078198                           776                 40344
# 1            2926328541                           736                 38293
# 2             307946374                           719                 37376
# 3             197822899                           827                 42983
# 4             312366933                           689                 35853
#
#    Employment Location Quotient Relative to U.S._y  \
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
#    Total Wage Location Quotient Relative to U.S._y  \
# 0                                              1.0
# 1                                              1.0
# 2                                              1.0
# 3                                              1.0
# 4                                              1.0
#
#    pct_jobs_tourism_leisure_hospitality
# 0                             14.216260
# 1                             20.823355
# 2                              9.248695
# 3                              4.345937
# 4                             10.342057

# %%
#keep only the columns needed
leisure = leisure[['Area\nCode', 'pct_jobs_tourism_leisure_hospitality']]

# %%
#merge with the rest of the clean data
education = pd.merge(education, leisure, left_on='FIPS', right_on='Area\nCode', how='left')

# %%
#drop unecessary column
education = education.drop(columns = ['Area\nCode'])

# %%
education.head()
# Out:
#                                      Location  pct_no_high_school_degree  \
# 0                       Kent County, Delaware                  12.565436
# 1                 New Castle County, Delaware                   8.356334
# 2                     Sussex County, Delaware                  11.879243
# 3  District of Columbia, District of Columbia                   9.076816
# 4                     Alachua County, Florida                   7.388892
#
#    pct_no_college_degree   FIPS  pct_poverty median_income  \
# 0              99.083470  10001         12.7       $58,804
# 1              99.356162  10003         10.4       $76,076
# 2              99.192569  10005         12.1       $64,839
# 3              99.585927  11001         14.1       $90,395
# 4              98.926612  12001         18.4       $49,880
#
#    pct_jobs_tourism_leisure_hospitality
# 0                             12.127023
# 1                             10.139226
# 2                             17.822374
# 3                             10.508416
# 4                             11.710262

# %% [markdown]
# # Evictions

# %%
#this data comes from The Eviction Lab

'''     CITE: This research uses data from The Eviction Lab at Princeton University, a project directed by Matthew Desmond and designed by Ashley Gromis, Lavar Edmonds, James Hendrickson, Katie Krywokulski, Lillian Leung, and Adam Porton. The Eviction Lab is funded by the JPB, Gates, and Ford Foundations as well as the Chan Zuckerberg Initiative. More information is found at evictionlab.org. '''
# Out:
# '     CITE: This research uses data from The Eviction Lab at Princeton University, a project directed by Matthew Desmond and designed by Ashley Gromis, Lavar Edmonds, James Hendrickson, Katie Krywokulski, Lillian Leung, and Adam Porton. The Eviction Lab is funded by the JPB, Gates, and Ford Foundations as well as the Chan Zuckerberg Initiative. More information is found at evictionlab.org. '

# %%
evictions = pd.read_csv('C:/Users/rgale/team_117/data/all-counties.csv')
evictions.head()
# Out:
#    GEOID  year                        name parent.location  population  \
# 0   2013  2009      Aleutians East Borough          Alaska      2959.0
# 1   2013  2010      Aleutians East Borough          Alaska      3141.0
# 2   2013  2013      Aleutians East Borough          Alaska      3304.0
# 3   2013  2015      Aleutians East Borough          Alaska      3304.0
# 4   2016  2016  Aleutians West Census Area          Alaska      5684.0
#
#    poverty.rate  renter.occupied.households  pct.renter.occupied  \
# 0          8.37                         263                58.59
# 1          6.28                         268                48.46
# 2         12.74                         274                46.52
# 3         12.74                         278                46.52
# 4          5.81                         849                67.75
#
#    median.gross.rent  median.household.income  median.property.value  \
# 0              654.0                  56250.0               122100.0
# 1              847.0                  58125.0               120900.0
# 2              930.0                  61518.0               126100.0
# 3              930.0                  61518.0               126100.0
# 4             1270.0                  84306.0               217500.0
#
#    rent.burden  pct.white  pct.af.am  pct.hispanic  pct.am.ind  pct.asian  \
# 0         18.0       9.97       9.83          9.50       17.17      47.48
# 1         20.6      13.53       6.75         12.26       27.67      35.43
# 2         22.0      14.98       9.17         12.05       29.00      30.51
# 3         22.0      14.98       9.17         12.05       29.00      30.51
# 4         19.4      27.76       4.61         10.96       12.95      36.77
#
#    pct.nh.pi  pct.multiple  pct.other  eviction.filings  evictions  \
# 0       0.34          5.58       0.14               0.0        NaN
# 1       0.60          3.72       0.03               0.0        NaN
# 2       1.12          3.18       0.00               0.0        NaN
# 3       1.12          3.18       0.00               0.0        NaN
# 4       2.45          4.40       0.11               0.0        NaN
#
#    eviction.rate  eviction.filing.rate  low.flag  imputed  subbed
# 0            NaN                   0.0         0        0       1
# 1            NaN                   0.0         0        0       1
# 2            NaN                   0.0         0        0       1
# 3            NaN                   0.0         0        0       1
# 4            NaN                   0.0         0        0       1
